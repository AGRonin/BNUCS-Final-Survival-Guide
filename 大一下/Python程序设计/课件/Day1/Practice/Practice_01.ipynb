# %% [markdown]
# 姓名：               学号：

# %% [markdown]
# ## <span style ="color: red">第1次作业</span>
#
# 编写程序，和电脑进行石头剪刀布游戏：电脑随机出拳，用户输入数字1/2/3键分别代表石头、剪刀和布进行游戏，按‘q’或‘Q’键则退出游戏。每一局游戏根据用户和电脑的出拳打印出输赢信息。游戏结束后，根据战况利用turtle绘制出笑脸（用户赢的次数多）、哭脸（用户赢的次数少）以及没表情的脸（用户和电脑相当），并显示战况统计情况。
